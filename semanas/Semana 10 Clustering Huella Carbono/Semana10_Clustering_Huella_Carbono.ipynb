# %% [markdown]
# # Semana 10 - Clustering de huella de carbono
#
# Se aplican estandarizacion, PCA, metodo del codo y K-Means para formar perfiles de huella. DBSCAN se utiliza como segunda mirada para reconocer observaciones atipicas o ruido.

# %%
from pathlib import Path
import runpy

raiz = Path.cwd()
while not (raiz / 'huella_carbono_pipeline.py').exists() and raiz != raiz.parent:
    raiz = raiz.parent
assert (raiz / 'huella_carbono_pipeline.py').exists(), 'Abra este notebook desde la carpeta del proyecto.'
runpy.run_path(str(raiz / 'semanas' / 'Semana 10 Clustering Huella Carbono' / 'semana10_clustering_huella.py'), run_name='__main__')
# Out:
# +----------+-----+
# |prediction|count|
# +----------+-----+
# |         0|   57|
# |         1|   49|
# |         2|   58|
# +----------+-----+
#
# +----------+-------------------------+
# |prediction|avg(intensidad_kgco2_mwh)|
# +----------+-------------------------+
# |         0|        438.1289762879715|
# |         1|       1199.1783337399736|
# |         2|       1161.2519629345306|
# +----------+-------------------------+
#
# Distribucion DBSCAN:
# cluster_dbscan
# -1    16
#  0    59
#  1    89
# Name: count, dtype: int64
# {'__name__': '__main__',
#  '__doc__': None,
#  '__package__': '',
#  '__loader__': None,
#  '__spec__': None,
#  '__file__': '/home/jovyan/work/semanas/Semana 10 Clustering Huella Carbono/semana10_clustering_huella.py',
#  '__cached__': None,
#  '__builtins__': {'__name__': 'builtins',
# ...

# %% [markdown]
# ## Evidencia esperada
#
# Los graficos muestran el criterio del codo y la distribucion PCA de los perfiles. Los datos pseudo-etiquetados por K-Means quedan preparados para la Semana 12.
