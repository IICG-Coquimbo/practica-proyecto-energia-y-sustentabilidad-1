# %%
# !pip install pymongo
# !pip install selenium
# !pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 2.9 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 2.5 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 3.4 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.7/135.7 kB 548.9 kB/s eta 0:00:000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.3/510.3 kB 2.1 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 171.4 kB/s eta 0:00:00 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 kB 429.9 kB/s eta 0:00:00 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.6/82.6 kB 165.8 kB/s eta 0:00:000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.5/67.5 kB 213.6 kB/s eta 0:00:000:00:01m
# ...
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 1.6.4
#     Uninstalling websocket-client-1.6.4:
# ...

# %%
import time
from pymongo import MongoClient
from selenium import webdriver
from selenium.webdriver.common.by import By

# 1. Configuración de metadatos y conexión
NOMBRE_GRUPO = "Energy"             
CATEGORIA_ACTUAL = "Energía y Sustentabilidad"  

try:
    client = MongoClient("database", 27017)
    db = client["proyecto_bigdata"]
    coleccion = db["datos_libros"]
    print("✅ CONEXIÓN EXITOSA: Listo para insertar datos de", CATEGORIA_ACTUAL)
except Exception as e:
    print("❌ ERROR DE CONEXIÓN:", e)
# Out:
# ✅ CONEXIÓN EXITOSA: Listo para insertar datos de Energía y Sustentabilidad

# %%
lista_libros = [
    {"titulo": "It’s Only Himalaya", "precio": "45.17"},
    {"titulo": "Full Moon over Noah’s Ark", "precio": "49.43"}
]

for libro in lista_libros:
    try:
        registro = {
            "item": libro["titulo"],
            "valor": float(libro["precio"].replace(" ", "").replace(",", "").strip()),
            "categoria": CATEGORIA_ACTUAL,
            "grupo": NOMBRE_GRUPO,
            "fecha_captura": time.strftime("%Y-%m-%d %H:%M:%S")
        }
        coleccion.insert_one(registro)
    except Exception as e:
        print("Error procesando libro:", e)

print("✅ PROCESO FINALIZADO: Datos enviados a MongoDB.")
# Out:
# ✅ PROCESO FINALIZADO: Datos enviados a MongoDB.

# %%
# Ver estructura de columnas
df.printSchema()

# Ver las primeras 5 filas
df.show(5)
