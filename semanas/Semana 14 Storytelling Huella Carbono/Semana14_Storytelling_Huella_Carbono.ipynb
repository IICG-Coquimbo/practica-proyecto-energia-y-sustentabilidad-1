# %% [markdown]
# # Semana 14 - Arco narrativo: contar historias con datos
#
# Este notebook recupera los datos ya procesados de huella de carbono de las semanas 9 y 10 para construir KPIs estrategicos, tacticos y operacionales.

# %%
# %run semana14_storytelling_huella.py

# %% [markdown]
# ## Salidas generadas
#
# - `salidas/kpi_estrategico_regiones.csv`
# - `salidas/kpi_tactico_tecnologias.csv`
# - `salidas/kpi_operacional_alertas.csv`
# - `salidas/guion_storytelling_semana14.md`
# - Graficos en `docs/evidencias_semana_14/`
