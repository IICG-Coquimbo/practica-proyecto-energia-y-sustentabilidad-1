# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

options = Options()
options.binary_location = "/usr/bin/brave-browser"

# --- CONFIGURACIÓN DE IMPACTO ---
options.add_argument("--headless=new")
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage") # <--- OBLIGA A NO USAR MEMORIA COMPARTIDA
options.add_argument("--disable-gpu")
options.add_argument("--disable-software-rasterizer")
options.add_argument("--remote-debugging-port=9222")
options.add_argument("--window-size=1920,1080")
options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36")

try:
    print("🔋 Iniciando motor de auditoría energética...")
    # Usamos un service para asegurar que el driver se limpie al fallar
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)
    
    print("🌍 Conectando con Amazon (Paneles Solares)...")
    driver.get("https://www.amazon.com/s?k=solar+panel+kit")
    
    # Si llegamos aquí, ¡FUNCIONÓ!
    print(f"✅ ÉXITO: Estamos en '{driver.title}'")
    
except Exception as e:
    print(f"❌ El error persiste: {e}")
# Out:
# 🔋 Iniciando motor de auditoría energética...
# ❌ El error persiste: Message: unknown error: Chrome failed to start: exited normally.
#   (chrome not reachable)
#   (The process started from chrome location /usr/bin/brave-browser is no longer running, so ChromeDriver is assuming that Chrome has crashed.)
# Stacktrace:
# #0 0x5b2266b844e3 <unknown>
# #1 0x5b22668b3c76 <unknown>
# #2 0x5b22668dcd78 <unknown>
# #3 0x5b22668d9029 <unknown>
# #4 0x5b2266917ccc <unknown>
# #5 0x5b226691747f <unknown>
# #6 0x5b226690ede3 <unknown>
# #7 0x5b22668e42dd <unknown>
# #8 0x5b22668e534e <unknown>
# #9 0x5b2266b443e4 <unknown>
# #10 0x5b2266b483d7 <unknown>
# #11 0x5b2266b52b20 <unknown>
# #12 0x5b2266b49023 <unknown>
# #13 0x5b2266b171aa <unknown>
# #14 0x5b2266b6d6b8 <unknown>
# #15 0x5b2266b6d847 <unknown>
# #16 0x5b2266b7d243 <unknown>
# #17 0x7397e5057ac3 <unknown>
